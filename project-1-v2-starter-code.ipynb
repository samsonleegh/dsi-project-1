# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
def generatePlayer(name: str) -> dict:
    global player_count
#     if not hasattr(generatePlayer, 'player_count'):
#         generatePlayer.player_count = 1
        
#     else:
#         generatePlayer.player_count += 1
    
    player_count += 1
    
    return {'player_id': player_count,
            'player_name': name,
            'time_played': 0.0,
            'player_pokemon': [],
            'gyms_visited': set()}

#     return {'player_id': generatePlayer.player_count,
#             'player_name': name,
#             'time_played': 0.0,
#             'player_pokemon': [],
#             'gyms_visited': set()}

players = {}
player_count = 0
pokemon_gyms = set(['reddit.com', 'amazon.com', 'twitter.com', 'linkedin.com', 'ebay.com', 'netflix.com', 'sporcle.com', 'stackoverflow.com', 'github.com', 'quora.com'])

# %%
player_one = generatePlayer('Ash')

player_one
# Out:
# {'gyms_visited': set(),
#  'player_id': 1,
#  'player_name': 'Ash',
#  'player_pokemon': [],
#  'time_played': 0.0}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
from random import sample

player_one['gyms_visited'].clear()
player_one['gyms_visited'].update(sample(pokemon_gyms, 2))

print(player_one['gyms_visited'])
# Out:
# {'sporcle.com', 'reddit.com'}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
def generatePokemon(pid: int, name: str, ptype: str, hp: int, attack: int, defence: int, sp_attack: int, sp_defence: int, speed: int) -> dict:
    return {'pokemon_id': pid, 'name': name, 'type': ptype, 'hp': hp, 'attack': attack, 'defence': defence, 'special_attack': sp_attack, 'special_defence': sp_defence, 'speed': speed}

pokedex = {1: generatePokemon(1,
                              'charmander', 
                              'fire', 
                              16, 
                              13, 
                              7, 
                              11, 
                              6, 
                              9),
           
           2: generatePokemon(2,
                              'squirtle', 
                              'water', 
                              18, 
                              11, 
                              11, 
                              10, 
                              13, 
                              8), 
           
           3: generatePokemon(3,
                              'bulbasaur', 
                              'poison', 
                              15, 
                              9, 
                              14, 
                              10, 
                              14, 
                              7)}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
players = {}

# %%
def addPlayer(player: dict):
    global players
    if not player['player_id'] in players:
        players[player['player_id']] = player
        
    else:
        raise ValueError('A player with ID {} already exists in the player database.'.format(player['player_id']), player)

addPlayer(player_one)

print(players)
# Out:
# {1: {'player_id': 1, 'player_name': 'Ash', 'time_played': 0.0, 'player_pokemon': [], 'gyms_visited': {'sporcle.com', 'reddit.com'}}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
player_two = generatePlayer('Gary')
player_two['gyms_visited'] = ['alcatraz', 'pacific_beach']
addPlayer(player_two)
print(players)
# Out:
# {1: {'player_id': 1, 'player_name': 'Ash', 'time_played': 0.0, 'player_pokemon': [], 'gyms_visited': {'sporcle.com', 'reddit.com'}}, 2: {'player_id': 2, 'player_name': 'Gary', 'time_played': 0.0, 'player_pokemon': [], 'gyms_visited': ['alcatraz', 'pacific_beach']}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
def clearPokemon(player_id):
    global players
    try:
        players[player_id]['player_pokemon'].clear()
    
    except KeyError:
        print('No player with ID {} found.'.format(player_id))
    
clearPokemon(1)
clearPokemon(2)

# %%
def givePokemon(player_id: int, pokemon_id: int):
    global players
    try:
        players[player_id]['player_pokemon'].append(pokedex[pokemon_id])
    
    except KeyError:
        print('No player with ID {} found.'.format(player_id))

# players[0]['player_pokemon'][2] = {k: v for k, v in pokedex[2].items()}
# players[2]['player_pokemon'][1] = {k: v for k, v in pokedex[1].items()}
# players[2]['player_pokemon'][3] = {k: v for k, v in pokedex[3].items()}

givePokemon(1, 2)
givePokemon(2, 1)
givePokemon(2, 3)

print(players[1]['player_pokemon'])
print(players[2]['player_pokemon'])
# Out:
# [{'pokemon_id': 2, 'name': 'squirtle', 'type': 'water', 'hp': 18, 'attack': 11, 'defence': 11, 'special_attack': 10, 'special_defence': 13, 'speed': 8}]
# [{'pokemon_id': 1, 'name': 'charmander', 'type': 'fire', 'hp': 16, 'attack': 13, 'defence': 7, 'special_attack': 11, 'special_defence': 6, 'speed': 9}, {'pokemon_id': 3, 'name': 'bulbasaur', 'type': 'poison', 'hp': 15, 'attack': 9, 'defence': 14, 'special_attack': 10, 'special_defence': 14, 'speed': 7}]

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
for gym in pokemon_gyms:
    for player_id in players:
        if gym in players[player_id]['gyms_visited']:
            print ('{} has visited {}'.format(players[player_id]['player_name'], gym))
# Out:
# Ash has visited sporcle.com
# Ash has visited reddit.com

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# Use a set instead of a list to hold the gyms each player has visited, then use set.intersection to find the intersection of a player's visited gyms with the set of gyms.
#
# Of course, all visited gyms should be a subset of the set of gyms, so there should be no need to refer to the set of gyms in the first place...

# %%
def getGymsVisited(player_id: int) -> set:
    gyms_visited = players[player_id]['gyms_visited'].intersection(pokemon_gyms)
    print ('{} has visited {}'.format(players[player_id]['player_name'], gyms_visited))
    return gyms_visited

# %%
getGymsVisited(1)
# Out:
# Ash has visited {'reddit.com', 'sporcle.com'}
# {'reddit.com', 'sporcle.com'}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
def getPower(players, pokedex, player_id):
    player_power = 0
    for pokemon in players[player_id]['player_pokemon']:
        pid = pokemon['pokemon_id']
        player_power += pokedex[pid]['attack'] + pokedex[pid]['defence']
    print("{}'s power is {}".format(players[player_id]['player_name'], player_power))
    
getPower(players, pokedex, 1)
getPower(players, pokedex, 2)
# Out:
# Ash's power is 22
# Gary's power is 43

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
# the pokedex string is assigned to the raw_pd variable

# %%
clean1 = raw_pd.split('\n')

# %%
#clean1

# %%
cleanraw = [line.replace('"','').split(',') for line in clean1]
header = cleanraw[0]
cleanraw.pop(0)

cleanraw2 = []
for line in cleanraw:
    newline = [str(int(line[0]))]
    for element in line[1:]:
        if element.isnumeric():
            newline.append(float(element))
        else:
            newline.append(element)    
    cleanraw2.append(newline)

# %%
#cleanraw2

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
cleanraw = [[str(int(line[0]))] + [float(element) if element.isnumeric() else element for element in line[1:]] for line in cleanraw]
assert(cleanraw == cleanraw2)
#print(cleanraw)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
def individualMegaTest(header: list, pokemon_one: list, pokemon_two: list) -> bool:
        '''Returns False if pokemon_one and pokemon_two have the same name but pokemon_two does not have an attribute 
        total higher than pokemon_one, and True otherwise.'''
    
        # these should actually be function attributes, but apparently Jupyter doesn't play nice with them...
    
        POKEMON_NAME = header.index('Name')
        POKEMON_TOTAL = header.index('Total')
    
        try:
            if pokemon_one[POKEMON_NAME] == pokemon_two[POKEMON_NAME].replace('Mega',''):
                if (int(pokemon[pokemon_two]) == int(pokemon_one[POKEMON_TOTAL]) - 100):
                    return True

                else: 
                    return False

            else:
                return True
            
        except IndexError:
            return True

def megaTest(source: list, header: list) -> bool:
    '''Tests if all Mega Evolution-capable Pokemon do indeed have the same Pokedex numbers as their normal forms and
    100 more of each stat.'''
    
    for index, pokemon in enumerate(source[:len(source) - 1]):
        next_pokemon = source[index + 1]
        if not individualMegaTest(header, pokemon, next_pokemon):
            return False
            
    return True         
            
megaTest(cleanraw, header)
# Out:
# True

# %%
# code duplication is bad

def individualMegaTest(header: list, pokemon_one: list, pokemon_two: list) -> bool:
        '''Returns True only if pokemon_one and pokemon_two have the same name and pokemon_two has an attribute 
        total higher than pokemon_one, and False otherwise.'''
    
        # these should actually be function attributes, but apparently Jupyter doesn't play nice with them...
    
        POKEMON_NAME = header.index('Name')
        POKEMON_TOTAL = header.index('Total')
    
        try:
            if pokemon_one[POKEMON_NAME] == pokemon_two[POKEMON_NAME].replace('Mega',''):
                if (int(pokemon_one[POKEMON_TOTAL]) == int(pokemon_two[POKEMON_TOTAL]) - 100):
                    return True

                else: 
                    return False

            else:
                return False
            
        except IndexError:
            return False

def generatePokedex(source: list, header: list, mode: int = 0) -> dict:
    def markDuplicates(source: list) -> str:
        import re
        last = 0
        count = 0
        for n in source:
            numeric_part = re.search(r'\d+', n).group()
            if last != numeric_part:
                yield n
                last = numeric_part
                count = 0                
            else:
                yield n + chr(ord('a') + count)
                count += 1
                
    POKEDEX_NUMBER_INDEX = header.index('PokedexNumber')
    
    transposed = list(zip(*source))
    
    # store pokedex as dict
    
    if mode == 0:
    
    # get rid of the number field in the header and mark duplicates with letters...
    
        header.pop(POKEDEX_NUMBER_INDEX)
        numbers = [n for n in transposed[POKEDEX_NUMBER_INDEX]]                            
        numbers = list(markDuplicates(numbers))
        
    # ...similarly, strip the pokemon numbers from the transposed (column-based) pokemon data, then transpose it again...

        pokedata = transposed[(POKEDEX_NUMBER_INDEX + 1):]
        pokedata = list(zip(*pokedata))
        
    # ...add a bool representing the ability to Mega Evolve, otherwise data will be lost...
    
        # header.append('Mega')
        # pokedata = [list(pokemon) + [individualMegaTest(header, pokemon, pokedata[index + 1])] for index, pokemon in enumerate(pokedata[:len(pokedata) - 1])]        

    # ...and use a dictionary comprehension to put everything together. Note that this doesn't actually capture all the
    # raw data, because there are some Pokemon with a mega form...
    
#         for number, data in zip(numbers, pokedata):
#             count = ord('a')
#             while number in pokedex.keys():
#                 number = number + chr(count)
#                 count += 1
#             pokedex[number] = {}
#             for h, d in zip(header, data):
#                 pokedex[number][h] = d
        
        return {number: {h: d for h, d in zip(header, data)} for number, data in zip(numbers, pokedata)}
        
    # store pokedex as list (should do it this way, I think, to handle duplicate pokemon numbers)
        
    else:        
        pass
    
if header[0] != 'PokedexNumber':
    header.insert(0, 'PokedexNumber')
while header[len(header) - 1] == 'Mega':
    header.pop()

pokedex = generatePokedex(cleanraw, header)

# %%
print(pokedex)
# Out:
# {'1': {'Name': 'Bulbasaur', 'Type': 'GrassPoison', 'Total': 318.0, 'HP': 45.0, 'Attack': 49.0, 'Defense': 49.0, 'SpecialAttack': 65.0, 'SpecialDefense': 65.0, 'Speed': 45.0}, '2': {'Name': 'Ivysaur', 'Type': 'GrassPoison', 'Total': 405.0, 'HP': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'SpecialAttack': 80.0, 'SpecialDefense': 80.0, 'Speed': 60.0}, '3': {'Name': 'Venusaur', 'Type': 'GrassPoison', 'Total': 525.0, 'HP': 80.0, 'Attack': 82.0, 'Defense': 83.0, 'SpecialAttack': 100.0, 'SpecialDefense': 100.0, 'Speed': 80.0}, '3a': {'Name': 'VenusaurMega Venusaur', 'Type': 'GrassPoison', 'Total': 625.0, 'HP': 80.0, 'Attack': 100.0, 'Defense': 123.0, 'SpecialAttack': 122.0, 'SpecialDefense': 120.0, 'Speed': 80.0}, '4': {'Name': 'Charmander', 'Type': 'Fire', 'Total': 309.0, 'HP': 39.0, 'Attack': 52.0, 'Defense': 43.0, 'SpecialAttack': 60.0, 'SpecialDefense': 50.0, 'Speed': 65.0}, '5': {'Name': 'Charmeleon', 'Type': 'Fire', 'Total': 405.0, 'HP': 58.0, 'Attack': 64.0, 'Defense': 58.0, 'SpecialAtta
# ...

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filterPokedex(pokedex: dict, filter_spec: dict, search_mode: int = 0) -> dict:
#    def applyFilter(t, f):
#        pass
    
    result = {k: v for k, v in pokedex.items()}

    if search_mode == 0:
        for k, v in filter_spec.items():
            try:
                result = dict(filter(lambda pokemon: pokemon[1][k].lower() == v.lower(), result.items()))

            except AttributeError:
                result = dict(filter(lambda pokemon: pokemon[1][k] >= v, result.items()))

# almost 6 times slower

    else:
        for p in pokedex:
            for f in filter_spec:
                try:
                    if pokedex[p][f].lower() != filter_spec[f].lower():
                        del result[p]

                except AttributeError:
                    if pokedex[p][f] < filter_spec[f]:
                        del result[p]
        
    return dict(result)

# %%
print(filterPokedex(pokedex, {}, 0))
# Out:
# {'1': {'Name': 'Bulbasaur', 'Type': 'GrassPoison', 'Total': 318.0, 'HP': 45.0, 'Attack': 49.0, 'Defense': 49.0, 'SpecialAttack': 65.0, 'SpecialDefense': 65.0, 'Speed': 45.0}, '2': {'Name': 'Ivysaur', 'Type': 'GrassPoison', 'Total': 405.0, 'HP': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'SpecialAttack': 80.0, 'SpecialDefense': 80.0, 'Speed': 60.0}, '3': {'Name': 'Venusaur', 'Type': 'GrassPoison', 'Total': 525.0, 'HP': 80.0, 'Attack': 82.0, 'Defense': 83.0, 'SpecialAttack': 100.0, 'SpecialDefense': 100.0, 'Speed': 80.0}, '3a': {'Name': 'VenusaurMega Venusaur', 'Type': 'GrassPoison', 'Total': 625.0, 'HP': 80.0, 'Attack': 100.0, 'Defense': 123.0, 'SpecialAttack': 122.0, 'SpecialDefense': 120.0, 'Speed': 80.0}, '4': {'Name': 'Charmander', 'Type': 'Fire', 'Total': 309.0, 'HP': 39.0, 'Attack': 52.0, 'Defense': 43.0, 'SpecialAttack': 60.0, 'SpecialDefense': 50.0, 'Speed': 65.0}, '5': {'Name': 'Charmeleon', 'Type': 'Fire', 'Total': 405.0, 'HP': 58.0, 'Attack': 64.0, 'Defense': 58.0, 'SpecialAtta
# ...

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
import numpy

dataset = [pokedata['Total'] for pokedata in pokedex.values()]
population_mean = numpy.mean(dataset)
population_std = numpy.std(dataset)

print('The population mean is {0:.2f}.'.format(population_mean))
print('The population standard deviation is {0:.2f}.'.format(population_std))
# Out:
# The population mean is 435.13.
# The population standard deviation is 119.96.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
import numpy

def findOverpowered(pokedex: dict) -> dict:
    dataset = [pokedata['Total'] for pokedata in pokedex.values()]
    population_mean = numpy.mean(dataset)
    population_std = numpy.std(dataset)
    threshold = population_mean + 3 * population_std
    #return [(pokemon[0], pokemon[2]) for pokemon in [data[1:4] for data in dataset][1:] if pokemon[2] > threshold]
    return [(number, pokedata) for number, pokedata in pokedex.items() if pokedata['Total'] >= threshold]

# %%
findOverpowered(pokedex)
# Out:
# [('150a',
#   {'Attack': 190.0,
#    'Defense': 100.0,
#    'HP': 126.0,
#    'Name': 'MewtwoMega Mewtwo X',
#    'SpecialAttack': 154.0,
#    'SpecialDefense': 100.0,
#    'Speed': 130.0,
#    'Total': 800.0,
#    'Type': 'PsychicFighting'})]

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %%
def getProbability(pokemon_number: int, power: int = None) -> float:
    from numpy import exp
    
    def calc(power):
        return min(1.27 / (numpy.exp((power / 23) ** 2 / 156)), 0.9)
    
    if power == None:
        power = pokedex[pokemon_number]['Total']
        probability = calc(power)
        print('The probability of getting {0}, which has total power {1}, is {2:.2%}.'.format(pokedex[p]['Name'], pokedex[p]['Total'], probability))
        
    else:        
        probability = calc(power)
        print('The probability of getting a {0} with total power {1}, is {2:.4%}.'.format(pokedex[p]['Name'], power, probability))
        
    return probability

# %%
for p in pokedex:
    getProbability(p)
# Out:
# The probability of getting Bulbasaur, which has total power 318.0, is 37.29%.
# The probability of getting Ivysaur, which has total power 405.0, is 17.40%.
# The probability of getting Venusaur, which has total power 525.0, is 4.50%.
# The probability of getting VenusaurMega Venusaur, which has total power 625.0, is 1.12%.
# The probability of getting Charmander, which has total power 309.0, is 39.93%.
# The probability of getting Charmeleon, which has total power 405.0, is 17.40%.
# The probability of getting Charizard, which has total power 534.0, is 4.01%.
# The probability of getting CharizardMega Charizard X, which has total power 634.0, is 0.97%.
# The probability of getting CharizardMega Charizard Y, which has total power 634.0, is 0.97%.
# The probability of getting Squirtle, which has total power 314.0, is 38.45%.
# The probability of getting Wartortle, which has total power 405.0, is 17.40%.
# The probability of getting Blastoise, which has total power 530.0, is 4.22%.
# ...
